# %%
import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/josi/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
idade=[32,18,45,19]
plt.plot(idade)

# %%
plt.plot([10, 12, 14, 19], idade)
plt.ylim(0,50)
plt.grid()
